# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Results](#results)
# * [Discussion](#discussion)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# The COVID-19 pandemic has severely affected lives, societies, and economies around the world. In Canada, Toronto has been particularly affected as a large metropolitan city home to roughly 3 million people and countless businesses. In the Downtown Toronto area, access to nearby medical centres is not evenly distributed for each neighborhood. It is of interest to Toronto Public Health, policy makers, and community leaders to determine which Toronto neighborhoods may be lacking access to adequate medical centres (clinics, hospitals, etc.) within walking distance. This access is important in the event an individual requires medical care, testing for COVID-19, and eventually for receiving vaccinations once they become available. Intervention may be required for neighborhoods with lower medical centre availability (pop-up centres, increased transportation options, etc.). As pharmacies can also be used for testing and vaccinations, we are also interested in looking at the number of pharmacies in each neighborhood. **The goal of this project will be to segment ___Downtown Toronto___ neighborhoods by their number of medical centres and pharmacies present.**

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# To group Downtown Toronto neighbourhoods by their number of medical centres and pharmacies present, the neighbourhoods will be clustered into three groups based on these metrics. This will help interested parties identify neighborhoods of greatest, medium, and least concern.
#
# To accomplish this, the following data is required:
# * A list of neighborhoods in Toronto with their corresponding latitude and longitude coordinates
# * A list of the medical centres (clinics, hospitals, etc.) present in each neighborhood, within 1 km of each latitude and longitude coordinate set (a reasonable walking distance)
# * A list of pharmacies present in each neighborhood, within 1 km of each latitude and longitude coordinate set (a reasonable walking distance)

# %% [markdown]
# ### Neighborhood Information

# %% [markdown]
# A list of Toronto neighborhoods with corresponding boroughs and postal codes are available from the Wikipedia page: \
# 'List of postal codes of Canada: M' (https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M).

# %% [markdown]
# The Wikipedia page is scraped to transfer neighborhood information to a Pandas dataframe.

# %% [markdown]
# First, importing Pandas:

# %%
import pandas as pd

# %% [markdown]
# The wikipedia page contains several tables. We are only interested in the first one, which we assign to a pandas dataframe and preview the dataframe:

# %%
wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df = pd.read_html(wiki, header=0)[0]
df.head(10)
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M1A      Not assigned                                          NaN
# 1         M2A      Not assigned                                          NaN
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 7         M8A      Not assigned                                          NaN
# 8         M9A         Etobicoke                             Islington Avenue
# 9         M1B       Scarborough                               Malvern, Rouge

# %% [markdown]
# Removing rows with unassigned boroughs:

# %%
df = df[df.Borough != 'Not assigned']
df.head(10)
# Out:
#    Postal Code           Borough                                 Neighborhood
# 2          M3A        North York                                    Parkwoods
# 3          M4A        North York                             Victoria Village
# 4          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5          M6A        North York             Lawrence Manor, Lawrence Heights
# 6          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 8          M9A         Etobicoke                             Islington Avenue
# 9          M1B       Scarborough                               Malvern, Rouge
# 11         M3B        North York                                    Don Mills
# 12         M4B         East York              Parkview Hill, Woodbine Gardens
# 13         M5B  Downtown Toronto                     Garden District, Ryerson

# %% [markdown]
# Determining the number of rows in the dataframe that we are dealing with:

# %%
print('The number of rows in the dataframe is', df.shape[0])
# Out:
# The number of rows in the dataframe is 103

# %% [markdown]
# #### Importing Latitude and Longitude Data

# %% [markdown]
# Importing the latitude and longitude data for each neighbourhood into a pandas dataframe from csv file: http://cocl.us/Geospatial_data:

# %%
geo_url = 'http://cocl.us/Geospatial_data'
geo_df = pd.read_csv(geo_url)
geo_df.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %% [markdown]
# Setting indices to 'Postal Code' for both dataframes to allow for merging, and merging the two dataframes into a new one:

# %%
geo_df = geo_df.set_index('Postal Code')
df = df.set_index('Postal Code')
all_df = pd.concat([df, geo_df], axis=1, join='outer', sort=False)
all_df.head(10)
# Out:
#               Borough                                 Neighborhood   Latitude  \
# M3A        North York                                    Parkwoods  43.753259
# M4A        North York                             Victoria Village  43.725882
# M5A  Downtown Toronto                    Regent Park, Harbourfront  43.654260
# M6A        North York             Lawrence Manor, Lawrence Heights  43.718518
# M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government  43.662301
# M9A         Etobicoke                             Islington Avenue  43.667856
# M1B       Scarborough                               Malvern, Rouge  43.806686
# M3B        North York                                    Don Mills  43.745906
# M4B         East York              Parkview Hill, Woodbine Gardens  43.706397
# M5B  Downtown Toronto                     Garden District, Ryerson  43.657162
#
#      Longitude
# M3A -79.329656
# M4A -79.315572
# M5A -79.360636
# M6A -79.464763
# M7A -79.389494
# M9A -79.532242
# M1B -79.194353
# M3B -79.352188
# M4B -79.309937
# M5B -79.378937

# %% [markdown]
# Resetting the index of the new dataframe and recover 'Postal Code' column title:

# %%
all_df.reset_index(inplace=True)
all_df.rename(columns={'index': 'Postal Code'},inplace=True)
all_df.head(10)
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 5         M9A         Etobicoke                             Islington Avenue
# 6         M1B       Scarborough                               Malvern, Rouge
# 7         M3B        North York                                    Don Mills
# 8         M4B         East York              Parkview Hill, Woodbine Gardens
# 9         M5B  Downtown Toronto                     Garden District, Ryerson
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494
# 5  43.667856 -79.532242
# 6  43.806686 -79.194353
# 7  43.745906 -79.352188
# 8  43.706397 -79.309937
# 9  43.657162 -79.378937

# %% [markdown]
# For this project, we are only interested in looking at Downtown Toronto neighborhoods:

# %%
dt_df = all_df[all_df.Borough == 'Downtown Toronto']
dt_df.head(10)
# Out:
#    Postal Code           Borough  \
# 2          M5A  Downtown Toronto
# 4          M7A  Downtown Toronto
# 9          M5B  Downtown Toronto
# 15         M5C  Downtown Toronto
# 20         M5E  Downtown Toronto
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 30         M5H  Downtown Toronto
# 36         M5J  Downtown Toronto
# 42         M5K  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 2                           Regent Park, Harbourfront  43.654260 -79.360636
# 4         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 9                            Garden District, Ryerson  43.657162 -79.378937
# 15                                     St. James Town  43.651494 -79.375418
# 20                                        Berczy Park  43.644771 -79.373306
# 24                                 Central Bay Street  43.657952 -79.387383
# 25                                           Christie  43.669542 -79.422564
# 30                           Richmond, Adelaide, King  43.650571 -79.384568
# 36  Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 42           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576

# %%
print('The number of rows in the dataframe is', dt_df.shape[0])
# Out:
# The number of rows in the dataframe is 19

# %% [markdown]
# Therefore we are dealing with **19 Downtown Toronto neighborhoods**. \
# Note: Some postal codes contain more than one neighborhood, listed together in one row. We will be dealing with these as one data point.

# %% [markdown]
# Let's reset the index in our dataframe and drop the old one:

# %%
dt_df.reset_index(inplace=True)
dt_df = dt_df.drop(columns='index')
dt_df
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 1          M7A  Downtown Toronto
# 2          M5B  Downtown Toronto
# 3          M5C  Downtown Toronto
# 4          M5E  Downtown Toronto
# 5          M5G  Downtown Toronto
# 6          M6G  Downtown Toronto
# 7          M5H  Downtown Toronto
# 8          M5J  Downtown Toronto
# 9          M5K  Downtown Toronto
# 10         M5L  Downtown Toronto
# 11         M5S  Downtown Toronto
# 12         M5T  Downtown Toronto
# 13         M5V  Downtown Toronto
# 14         M4W  Downtown Toronto
# 15         M5W  Downtown Toronto
# 16         M4X  Downtown Toronto
# 17         M5X  Downtown Toronto
# 18         M4Y  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                           Regent Park, Harbourfront  43.654260 -79.360636
# 1         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                            Garden District, Ryerson  43.657162 -79.378937
# 3                                      St. James Town  43.651494 -79.375418
# 4                                         Berczy Park  43.644771 -79.373306
# 5                                  Central Bay Street  43.657952 -79.387383
# 6                                            Christie  43.669542 -79.422564
# 7                            Richmond, Adelaide, King  43.650571 -79.384568
# 8   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 9            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 10                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 11                     University of Toronto, Harbord  43.662696 -79.400049
# 12          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 13  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 14                                           Rosedale  43.679563 -79.377529
# 15                                     Stn A PO Boxes  43.646435 -79.374846
# 16                        St. James Town, Cabbagetown  43.667967 -79.367675
# 17             First Canadian Place, Underground city  43.648429 -79.382280
# 18                               Church and Wellesley  43.665860 -79.383160

# %% [markdown]
# Let's visualize the neighborhoods by superimposing them on a map of Toronto.
#
# Importing geopy and folium:

# %%
#!pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

#!pip install folium==0.5.0
import folium # map rendering library

# %% [markdown]
# Obtaining latitude and longitude coordinates of Toronto for mapping:

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# #### Downtown Toronto Neighborhoods Superimposed on Map

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, borough, neighborhood in zip(dt_df['Latitude'], dt_df['Longitude'], dt_df['Borough'], dt_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Foursquare

# %% [markdown]
# Now that we have our neighborhood location data, let's use Foursquare API to get venue information for each neighborhood.

# %% [markdown]
# Defining Foursquare credentials and version:

# %%
CLIENT_ID = 'U4FBECMV3D0DKSFWFHCAWQFOGZ0YUEBI2DTZDBCFCYHHO0FI' # my Foursquare ID
CLIENT_SECRET = 'LJZD1ROUJCT5UAMJJO4IDY3WB55BEPXXBOGQTPUAXB2MVWS3' # my Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: U4FBECMV3D0DKSFWFHCAWQFOGZ0YUEBI2DTZDBCFCYHHO0FI
# CLIENT_SECRET:LJZD1ROUJCT5UAMJJO4IDY3WB55BEPXXBOGQTPUAXB2MVWS3

# %% [markdown]
# We will be obtaining venue data for each neighborhood using a pre-defined radius of 1 km around the listed latitude and longitude coordinates. Our search query, to encompass all types of medical centres (clinics, hospitals, etc.) will be 'medical':

# %%
radius = 1000
LIMIT = 100
search_query = 'medical'

# %% [markdown]
# As an example, let's obtain a list of medical centres in one Downtown Toronto neighbourhood, St. James Town, whose index number in our dataframe is 3. Let's obtain the latitude and longitude coordinates of the neighborhood from our dataframe:

# %%
latitude = dt_df.loc[3,'Latitude']
longitude = dt_df.loc[3,'Longitude']

# %% [markdown]
# Generating an URL for our search call to the Foursquare API:

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=U4FBECMV3D0DKSFWFHCAWQFOGZ0YUEBI2DTZDBCFCYHHO0FI&client_secret=LJZD1ROUJCT5UAMJJO4IDY3WB55BEPXXBOGQTPUAXB2MVWS3&ll=43.6514939,-79.3754179&v=20180604&query=medical&radius=1000&limit=100'

# %% [markdown]
# Executing our **get** request:

# %%
import requests

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ec5a578aba297001c3ae87c'},
#  'response': {'venues': [{'id': '4cdf5495f8cdb1f738339112',
#     'name': "St Michael's Hospital Medical Imaging",
#     'location': {'address': '30 Bond St.',
#      'lat': 43.65368444376282,
#      'lng': -79.37870569300675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65368444376282,
#        'lng': -79.37870569300675}],
#      'distance': 359,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['30 Bond St.', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '55ace30f498e675077de6b47',
#     'name': 'Oxford Medical Imaging',
#     'location': {'address': '11 King St West',
#      'lat': 43.648542,
#      'lng': -79.37856,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648542,
#        'lng': -79.37856}],
#      'distance': 414,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['11 King St West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4f4531b14b9074f6e4fb0103',
#       'name': 'Medical Lab',
#       'pluralName': 'Medical Labs',
#       'shortName': 'Medical Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4bd8761309ecb713ffe6487c',
#     'name': 'The Toronto Centre For Medical Imaging',
#     'location': {'address': '150 York Street, Suite 910',
#      'crossStreet': 'Adelaide Street',
#      'lat': 43.64960424693243,
#      'lng': -79.38444240296869,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64960424693243,
#        'lng': -79.38444240296869}],
#      'distance': 756,
#      'postalCode': 'M5H 3S5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['150 York Street, Suite 910 (Adelaide Street)',
#       'Toronto ON M5H 3S5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4df0e138d4c04d0392c7e652',
#     'name': 'CIRA Medical Centre',
#     'location': {'address': '180 Dundas St. W',
#      'crossStreet': 'at Chestnut St.',
#      'lat': 43.655395,
#      'lng': -79.386459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655395,
#        'lng': -79.386459}],
#      'distance': 989,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['180 Dundas St. W (at Chestnut St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4f92e56de4b04c3ff96a5aa5',
#     'name': 'Carlton + Church Medical Clinic',
#     'location': {'address': '80 Carlton Street',
#      'crossStreet': 'Church Street',
#      'lat': 43.66191203164747,
#      'lng': -79.37979761978043,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66191203164747,
#        'lng': -79.37979761978043}],
#      'distance': 1212,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['80 Carlton Street (Church Street)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4bb10c59f964a520be753ce3',
#     'name': 'Medical Building',
#     'location': {'address': '123 Edward St',
#      'crossStreet': 'University and Edward',
#      'lat': 43.655812995450354,
#      'lng': -79.38684377764326,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655812995450354,
#        'lng': -79.38684377764326}],
#      'distance': 1038,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Edward St (University and Edward)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4f4b8411e4b05ebee2ac99d9',
#     'name': 'Goodlife Medical Centre',
#     'location': {'lat': 43.6517138684258,
#      'lng': -79.37878038252616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6517138684258,
#        'lng': -79.37878038252616}],
#      'distance': 271,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4ea70e4249011f90212b9db9',
#     'name': 'Medisys Health Group Medical Imaging Services',
#     'location': {'address': '123 Edward St.',
#      'lat': 43.651215,
#      'lng': -79.368703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651215,
#        'lng': -79.368703}],
#      'distance': 541,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Edward St.', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4f201179e4b0294b35474fd3',
#     'name': 'Tailor Medical',
#     'location': {'lat': 43.65094770124931,
#      'lng': -79.380297986438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65094770124931,
#        'lng': -79.380297986438}],
#      'distance': 397,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '50cf7600e4b07c15503d4afb',
#     'name': 'Medical Building',
#     'location': {'address': '123 Edward Street',
#      'lat': 43.656994430019175,
#      'lng': -79.38415236861843,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656994430019175,
#        'lng': -79.38415236861843}],
#      'distance': 932,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Edward Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4da70251f7b15dc952f07e3f',
#     'name': 'Appletree Medical Group',
#     'location': {'address': '53 Yonge Street, Suite 400',
#      'lat': 43.647938,
#      'lng': -79.377661,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647938,
#        'lng': -79.377661}],
#      'distance': 435,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['53 Yonge Street, Suite 400',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '538e3c86498eb2165c025250',
#     'name': 'Medical Compassion Clinic',
#     'location': {'address': '127 Church Street',
#      'crossStreet': 'Queen & Church',
#      'lat': 43.642390641072616,
#      'lng': -79.37567911459557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642390641072616,
#        'lng': -79.37567911459557}],
#      'distance': 1013,
#      'postalCode': 'M5C 2G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['127 Church Street (Queen & Church)',
#       'Toronto ON M5C 2G5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '5e75c3b9b66ad900076c27ae',
#     'name': "Traveller's Medical Service & Geographic Medicine Clinic",
#     'location': {'address': '401-372 Bay St',
#      'lat': 43.651014,
#      'lng': -79.381223,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651014,
#        'lng': -79.381223}],
#      'distance': 470,
#      'postalCode': 'M5H 2W9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['401-372 Bay St', 'Toronto ON M5H 2W9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4d0f9341d21db60cc2ec2418',
#     'name': 'Appletree Medical Group',
#     'location': {'address': '140 The Esplanade',
#      'crossStreet': 'Lower Jarvis',
#      'lat': 43.648456,
#      'lng': -79.37098,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648456,
#        'lng': -79.37098}],
#      'distance': 492,
#      'postalCode': 'M5A 4P5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['140 The Esplanade (Lower Jarvis)',
#       'Toronto ON M5A 4P5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4b8838c4f964a5207fe831e3',
#     'name': 'First Canadian Medical Centre',
#     'location': {'address': 'First Canadian Place',
#      'crossStreet': 'York St.',
#      'lat': 43.649325376465136,
#      'lng': -79.3818947427396,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649325376465136,
#        'lng': -79.3818947427396}],
#      'distance': 574,
#      'postalCode': 'M5X 1A4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['First Canadian Place (York St.)',
#       'Toronto ON M5X 1A4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4f6ccbb6e4b09530adbd5283',
#     'name': "traveller's medical service & geographic medicine",
#     'location': {'lat': 43.65226481508192,
#      'lng': -79.3822884292271,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65226481508192,
#        'lng': -79.3822884292271}],
#      'distance': 559,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4b8e90ecf964a520122933e3',
#     'name': 'MCI Medical Clinic',
#     'location': {'address': '595 Bay St.',
#      'crossStreet': 'in Atrium on Bay',
#      'lat': 43.65613745484842,
#      'lng': -79.38345395206551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65613745484842,
#        'lng': -79.38345395206551}],
#      'distance': 828,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St. (in Atrium on Bay)',
#       'Toronto ON M5G 2C2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4cc19a13e310224bf4f9306f',
#     'name': 'Royal Medical Centre',
#     'location': {'lat': 43.64617527136308,
#      'lng': -79.37950619619555,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64617527136308,
#        'lng': -79.37950619619555}],
#      'distance': 677,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '566f4edb498e7642ed574646',
#     'name': 'Well One Medical Centre',
#     'location': {'address': '18 Yonge St',
#      'lat': 43.64424663496144,
#      'lng': -79.37607017009026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64424663496144,
#        'lng': -79.37607017009026}],
#      'distance': 808,
#      'postalCode': 'M5E 1Z8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['18 Yonge St', 'Toronto ON M5E 1Z8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4d25ece0002f5481a3efa4f3',
#     'name': 'Medvue Medical Imaging',
#     'location': {'lat': 43.65604750453975,
#      'lng': -79.38672003486646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65604750453975,
#        'lng': -79.38672003486646}],
#      'distance': 1041,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '5e1fd3b6dace800007b0a878',
#     'name': 'Appletree Medical Centre',
#     'location': {'address': '70 University Avenue',
#      'lat': 43.6467,
#      'lng': -79.38437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6467,
#        'lng': -79.38437}],
#      'distance': 897,
#      'postalCode': 'M5J 2M4',
#      'cc': 'CA',
#      'neighborhood': 'Entertainment District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['70 University Avenue',
#       'Toronto ON M5J 2M4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '58010d2238fa3ca5ed063e1d',
#     'name': 'Titan Medical Inc',
#     'location': {'lat': 43.648657,
#      'lng': -79.386071,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648657,
#        'lng': -79.386071}],
#      'distance': 914,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '56df2daf498ef152450c9893',
#     'name': 'Queens Quay Medical',
#     'location': {'lat': 43.644325,
#      'lng': -79.369436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644325,
#        'lng': -79.369436}],
#      'distance': 932,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '53c3e8b8498eef9fa6d4ed6b',
#     'name': 'Primacy medical clinic',
#     'location': {'address': '10 lower Jarvis',
#      'lat': 43.6443,
#      'lng': -79.3696,
#      'labeledLatLngs': [{'label': 'display', 'lat': 43.6443, 'lng': -79.3696}],
#      'distance': 927,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 lower Jarvis', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4f4bee98e4b05ebee3312932',
#     'name': 'Ryerson Medical centre',
#     'location': {'address': '181 Kerr Hall West',
#      'crossStreet': '350 Victoria Street',
#      'lat': 43.659217011692476,
#      'lng': -79.38051242846358,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.659217011692476,
#        'lng': -79.38051242846358}],
#      'distance': 952,
#      'postalCode': 'M5B 2K3',
#      'cc': 'CA',
#      'neighborhood': 'Downtown Toronto',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['181 Kerr Hall West (350 Victoria Street)',
#       'Toronto ON M5B 2K3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4bfeeacb369476b0490f8d1f',
#     'name': 'Albany Medical Clinic',
#     'location': {'lat': 43.650528745677136,
#      'lng': -79.3883474695189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650528745677136,
#        'lng': -79.3883474695189}],
#      'distance': 1046,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '54a72f4e498ef4dcbc2e4628',
#     'name': 'Royal Care Medical',
#     'location': {'address': '407 Yonge Street',
#      'lat': 43.659502234850365,
#      'lng': -79.38198601664295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.659502234850365,
#        'lng': -79.38198601664295}],
#      'distance': 1036,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['407 Yonge Street', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '53a788f9498e70c5a31adb95',
#     'name': 'GIC Medical Disposal',
#     'location': {'address': '2nd Floor – 243 Queen Street W',
#      'lat': 43.650461721026176,
#      'lng': -79.38807606697083,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650461721026176,
#        'lng': -79.38807606697083}],
#      'distance': 1026,
#      'postalCode': 'M5V 1Z4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2nd Floor – 243 Queen Street W',
#       'Toronto ON M5V 1Z4',
#       'Canada']},
#     'categories': [{'id': '4f4531b14b9074f6e4fb0103',
#       'name': 'Medical Lab',
#       'pluralName': 'Medical Labs',
#       'shortName': 'Medical Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4b8e5c3af964a520aa1e33e3',
#     'name': 'Gamma Dynacare Medical Laboratories',
#     'location': {'address': '808-123 Edward St',
#      'crossStreet': 'at Centre Ave',
#      'lat': 43.65501,
#      'lng': -79.386741,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65501,
#        'lng': -79.386741}],
#      'distance': 992,
#      'postalCode': 'M5G 1E2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['808-123 Edward St (at Centre Ave)',
#       'Toronto ON M5G 1E2',
#       'Canada']},
#     'categories': [{'id': '4f4531b14b9074f6e4fb0103',
#       'name': 'Medical Lab',
#       'pluralName': 'Medical Labs',
#       'shortName': 'Medical Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4b7326d9f964a520929e2de3',
#     'name': 'Six Degrees Medical Consulting',
#     'location': {'address': '175 Bloor Street East, Suite 901',
#      'crossStreet': 'Church Street',
#      'lat': 43.64174607465404,
#      'lng': -79.37683589059087,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64174607465404,
#        'lng': -79.37683589059087}],
#      'distance': 1091,
#      'postalCode': 'M4W 3R8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['175 Bloor Street East, Suite 901 (Church Street)',
#       'Toronto ON M4W 3R8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '591a34e4ea1e445e563d6dbf',
#     'name': 'Appletree Medical Group',
#     'location': {'address': '8 York Street',
#      'lat': 43.640394,
#      'lng': -79.380592,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.640394,
#        'lng': -79.380592}],
#      'distance': 1304,
#      'postalCode': 'M5J 2Y2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['8 York Street', 'Toronto ON M5J 2Y2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '4ed56a6e7beb820a77c42e58',
#     'name': 'Loblaws',
#     'location': {'address': '60 Carlton St',
#      'crossStreet': 'at Church St',
#      'lat': 43.661876101184674,
#      'lng': -79.37970103481895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661876101184674,
#        'lng': -79.37970103481895}],
#      'distance': 1206,
#      'postalCode': 'M5B 1J2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['60 Carlton St (at Church St)',
#       'Toronto ON M5B 1J2',
#       'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#       'name': 'Supermarket',
#       'pluralName': 'Supermarkets',
#       'shortName': 'Supermarket',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '578cfc43cd108caadc9632d6',
#     'name': 'MyoMedical',
#     'location': {'address': '145 Front St E',
#      'lat': 43.649969,
#      'lng': -79.369533,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649969,
#        'lng': -79.369533}],
#      'distance': 503,
#      'postalCode': 'M5A 1E3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['145 Front St E', 'Toronto ON M5A 1E3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False},
#    {'id': '55681367498e061c1286c73d',
#     'name': 'MarxMedical',
#     'location': {'address': '100 King Street West, Suite 5600,',
#      'lat': 43.64736420341369,
#      'lng': -79.38465893268585,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64736420341369,
#        'lng': -79.38465893268585}],
#      'distance': 874,
#      'postalCode': 'M5X 1C9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 King Street West, Suite 5600,',
#       'Toronto ON M5X 1C9',
#       'Canada']},
#     'categories': [{'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'shortName': 'Health & Beauty',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011689',
#     'hasPerk': False}]}}

# %% [markdown]
# How many results, i.e. venues featuring the keyword 'medical', did our search query obtain?

# %%
venues = results['response']['venues']
print('There are {} medical centres in St. James Town.'.format(len(venues)))
# Out:
# There are 34 medical centres in St. James Town.

# %% [markdown]
# Therefore there are **34 medical centres in St. James Town**. Let's repeat the query for each of our 19 neighborhoods and store the results in a list.

# %%
medical_list = []
for row in range(dt_df.shape[0]):
    latitude = dt_df.loc[row,'Latitude']
    longitude = dt_df.loc[row,'Longitude']
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    results = requests.get(url).json()
    venues = results['response']['venues']
    medical_list.append(len(venues))
medical_list
# Out:
# [5, 48, 48, 34, 20, 50, 9, 48, 22, 36, 34, 38, 38, 2, 3, 23, 8, 43, 39]

# %% [markdown]
# Let's convert this list to a column in our dataframe, dt_df, and preview the changes.

# %%
dt_df['Medical Centres'] = medical_list
dt_df
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 1          M7A  Downtown Toronto
# 2          M5B  Downtown Toronto
# 3          M5C  Downtown Toronto
# 4          M5E  Downtown Toronto
# 5          M5G  Downtown Toronto
# 6          M6G  Downtown Toronto
# 7          M5H  Downtown Toronto
# 8          M5J  Downtown Toronto
# 9          M5K  Downtown Toronto
# 10         M5L  Downtown Toronto
# 11         M5S  Downtown Toronto
# 12         M5T  Downtown Toronto
# 13         M5V  Downtown Toronto
# 14         M4W  Downtown Toronto
# 15         M5W  Downtown Toronto
# 16         M4X  Downtown Toronto
# 17         M5X  Downtown Toronto
# 18         M4Y  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 0                           Regent Park, Harbourfront  43.654260 -79.360636
# 1         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                            Garden District, Ryerson  43.657162 -79.378937
# 3                                      St. James Town  43.651494 -79.375418
# 4                                         Berczy Park  43.644771 -79.373306
# 5                                  Central Bay Street  43.657952 -79.387383
# 6                                            Christie  43.669542 -79.422564
# 7                            Richmond, Adelaide, King  43.650571 -79.384568
# 8   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 9            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 10                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 11                     University of Toronto, Harbord  43.662696 -79.400049
# 12          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 13  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 14                                           Rosedale  43.679563 -79.377529
# 15                                     Stn A PO Boxes  43.646435 -79.374846
# 16                        St. James Town, Cabbagetown  43.667967 -79.367675
# 17             First Canadian Place, Underground city  43.648429 -79.382280
# 18                               Church and Wellesley  43.665860 -79.383160
#
#     Medical Centres
# 0                 5
# 1                48
# 2                48
# 3                34
# 4                20
# 5                50
# 6                 9
# 7                48
# 8                22
# 9                36
# 10               34
# 11               38
# 12               38
# 13                2
# 14                3
# 15               23
# 16                8
# 17               43
# 18               39

# %% [markdown]
# Let's repeat this process to obtain the number of pharmacies for each neighborhood.

# %%
search_query = 'pharmacy'

# %% [markdown]
# As an example, let's obtain a list of pharmacies in St. James Town:

# %%
latitude = dt_df.loc[3,'Latitude']
longitude = dt_df.loc[3,'Longitude']

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=U4FBECMV3D0DKSFWFHCAWQFOGZ0YUEBI2DTZDBCFCYHHO0FI&client_secret=LJZD1ROUJCT5UAMJJO4IDY3WB55BEPXXBOGQTPUAXB2MVWS3&ll=43.6514939,-79.3754179&v=20180604&query=pharmacy&radius=1000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ec5a61d211536001b257dfd'},
#  'response': {'venues': [{'id': '5c6474c3033693002ccba1bb',
#     'name': 'Wellth Pharmacy',
#     'location': {'address': '85 Church St',
#      'lat': 43.65176,
#      'lng': -79.375062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65176,
#        'lng': -79.375062}],
#      'distance': 41,
#      'postalCode': 'M5C 2G2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['85 Church St', 'Toronto ON M5C 2G2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4f1de655e4b0e2eeede3ac0e',
#     'name': "Guardian - Morelli's Pharmacy",
#     'location': {'address': '15 York St',
#      'lat': 43.642418,
#      'lng': -79.380937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642418,
#        'lng': -79.380937}],
#      'distance': 1103,
#      'postalCode': 'M5J 0A3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['15 York St', 'Toronto ON M5J 0A3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4ad87cf2f964a520bd1121e3',
#     'name': 'Metro Pharmacy',
#     'location': {'address': '80 Front St E',
#      'crossStreet': 'at Church St',
#      'lat': 43.64901359997141,
#      'lng': -79.37286254600622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64901359997141,
#        'lng': -79.37286254600622}],
#      'distance': 344,
#      'postalCode': 'M5E 1T4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['80 Front St E (at Church St)',
#       'Toronto ON M5E 1T4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4f0f0eb8e4b023b37a7102fd',
#     'name': 'Woodgreen Pharmacy',
#     'location': {'address': '69 Queen St east',
#      'lat': 43.65326412257316,
#      'lng': -79.37633896753167,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65326412257316,
#        'lng': -79.37633896753167}],
#      'distance': 210,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['69 Queen St east', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4ca60748d971b1f7a5f8fbe0',
#     'name': 'Yonge Pharmacy',
#     'location': {'address': '159 yonge st',
#      'lat': 43.652174188201464,
#      'lng': -79.3790608112091,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652174188201464,
#        'lng': -79.3790608112091}],
#      'distance': 303,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['159 yonge st', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '590ab207a6fe4d717e31f503',
#     'name': 'Pharmacy Technician Resources',
#     'location': {'address': '1 Yonge Street',
#      'crossStreet': 'Suite 32609',
#      'lat': 43.64310039150323,
#      'lng': -79.37478303909302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64310039150323,
#        'lng': -79.37478303909302}],
#      'distance': 935,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Yonge Street (Suite 32609)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'shortName': 'Health & Beauty',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4e6e62d28877d6d0b13220c6',
#     'name': 'Metro Pharmacy',
#     'location': {'address': '129 Dundas',
#      'crossStreet': 'Dalhousie',
#      'lat': 43.655955201228316,
#      'lng': -79.37449136746727,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655955201228316,
#        'lng': -79.37449136746727}],
#      'distance': 502,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['129 Dundas (Dalhousie)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4dd581be1f6ee14682f390cc',
#     'name': 'St Lawrence Pharmacy',
#     'location': {'lat': 43.649269,
#      'lng': -79.367017,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649269,
#        'lng': -79.367017}],
#      'distance': 720,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '5ab93879c97f2864fb108675',
#     'name': 'Loblaw pharmacy',
#     'location': {'address': '200 Front St E',
#      'lat': 43.6514188,
#      'lng': -79.3659472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6514188,
#        'lng': -79.3659472}],
#      'distance': 762,
#      'postalCode': 'M5A 4T9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Front St E', 'Toronto ON M5A 4T9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4c1fe013920076b0ce6cc5e9',
#     'name': 'Guardian Pharmacy',
#     'location': {'address': '755 Dundas St. W',
#      'crossStreet': 'Bathurst & Dundas',
#      'lat': 43.655781,
#      'lng': -79.383859,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655781,
#        'lng': -79.383859}],
#      'distance': 830,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['755 Dundas St. W (Bathurst & Dundas)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '5aeb133f89ad46002470bc79',
#     'name': 'DRUGStore Pharmacy',
#     'location': {'address': '10 Lower Jarvis St',
#      'lat': 43.644693533684396,
#      'lng': -79.36994433403015,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644693533684396,
#        'lng': -79.36994433403015}],
#      'distance': 876,
#      'postalCode': 'M5E 1Z2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Lower Jarvis St',
#       'Toronto ON M5E 1Z2',
#       'Canada']},
#     'categories': [{'id': '522e32fae4b09b556e370f19',
#       'name': 'Eye Doctor',
#       'pluralName': 'Eye Doctors',
#       'shortName': 'Eye Doctor',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '5ab936e05a2c914c7ac15c82',
#     'name': 'DRUGStore Pharmacy',
#     'location': {'address': '10 Lower Jarvis St',
#      'lat': 43.6445862,
#      'lng': -79.3700423,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6445862,
#        'lng': -79.3700423}],
#      'distance': 882,
#      'postalCode': 'M5E 1Z2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Lower Jarvis St',
#       'Toronto ON M5E 1Z2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4bf56488cad2c928ddfa9c99',
#     'name': 'Victor Pharmacy',
#     'location': {'address': '123 Edward St.',
#      'crossStreet': 'at Chestnut',
#      'lat': 43.655444634146946,
#      'lng': -79.3863351643787,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655444634146946,
#        'lng': -79.3863351643787}],
#      'distance': 983,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Edward St. (at Chestnut)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '53399348498e18d7e6bbbb62',
#     'name': 'Loblaw pharmacy',
#     'location': {'address': '60 Carlton St',
#      'crossStreet': 'Church and Carleton',
#      'lat': 43.662128,
#      'lng': -79.380147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.662128,
#        'lng': -79.380147}],
#      'distance': 1243,
#      'postalCode': 'M5B 1J2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['60 Carlton St (Church and Carleton)',
#       'Toronto ON M5B 1J2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '4c20dd888082d13a1851f82a',
#     'name': 'Ultra Pharmacy',
#     'location': {'address': '411 Parliament',
#      'crossStreet': 'Gerrard',
#      'lat': 43.661327,
#      'lng': -79.366405,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661327,
#        'lng': -79.366405}],
#      'distance': 1313,
#      'cc': 'CA',
#      'city': 'Toronto Division',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['411 Parliament (Gerrard)',
#       'Toronto Division ON',
#       'Canada']},
#     'categories': [],
#     'referralId': 'v-1590011742',
#     'hasPerk': False},
#    {'id': '51118478e4b00424e53e17fc',
#     'name': 'pharmacy.ca',
#     'location': {'address': 'Shernourne',
#      'crossStreet': 'Gerrard',
#      'lat': 43.65856244529446,
#      'lng': -79.37526670412389,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65856244529446,
#        'lng': -79.37526670412389}],
#      'distance': 786,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Shernourne (Gerrard)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590011742',
#     'hasPerk': False}]}}

# %% [markdown]
# How many results, i.e. venues featuring the keyword 'pharmacy', did our search query obtain?

# %%
venues = results['response']['venues']
print('There are {} pharmacies in St. James Town.'.format(len(venues)))
# Out:
# There are 16 pharmacies in St. James Town.

# %% [markdown]
# Therefore there are **16 pharmacies in St. James Town**. Let's repeat the query for each of our 19 neighborhoods and store the results in a list.

# %%
pharmacy_list = []
for row in range(dt_df.shape[0]):
    latitude = dt_df.loc[row,'Latitude']
    longitude = dt_df.loc[row,'Longitude']
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
    results = requests.get(url).json()
    venues = results['response']['venues']
    pharmacy_list.append(len(venues))
pharmacy_list
# Out:
# [9, 22, 24, 16, 10, 27, 9, 22, 4, 15, 16, 16, 25, 1, 1, 10, 9, 19, 17]

# %% [markdown]
# Let's convert this list to a column in our dataframe, dt_df, and preview the changes.

# %%
dt_df['Pharmacies'] = pharmacy_list
dt_df
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 1          M7A  Downtown Toronto
# 2          M5B  Downtown Toronto
# 3          M5C  Downtown Toronto
# 4          M5E  Downtown Toronto
# 5          M5G  Downtown Toronto
# 6          M6G  Downtown Toronto
# 7          M5H  Downtown Toronto
# 8          M5J  Downtown Toronto
# 9          M5K  Downtown Toronto
# 10         M5L  Downtown Toronto
# 11         M5S  Downtown Toronto
# 12         M5T  Downtown Toronto
# 13         M5V  Downtown Toronto
# 14         M4W  Downtown Toronto
# 15         M5W  Downtown Toronto
# 16         M4X  Downtown Toronto
# 17         M5X  Downtown Toronto
# 18         M4Y  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 0                           Regent Park, Harbourfront  43.654260 -79.360636
# 1         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                            Garden District, Ryerson  43.657162 -79.378937
# 3                                      St. James Town  43.651494 -79.375418
# 4                                         Berczy Park  43.644771 -79.373306
# 5                                  Central Bay Street  43.657952 -79.387383
# 6                                            Christie  43.669542 -79.422564
# 7                            Richmond, Adelaide, King  43.650571 -79.384568
# 8   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 9            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 10                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 11                     University of Toronto, Harbord  43.662696 -79.400049
# 12          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 13  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 14                                           Rosedale  43.679563 -79.377529
# 15                                     Stn A PO Boxes  43.646435 -79.374846
# 16                        St. James Town, Cabbagetown  43.667967 -79.367675
# 17             First Canadian Place, Underground city  43.648429 -79.382280
# 18                               Church and Wellesley  43.665860 -79.383160
#
#     Medical Centres  Pharmacies
# 0                 5           9
# 1                48          22
# 2                48          24
# 3                34          16
# 4                20          10
# 5                50          27
# 6                 9           9
# 7                48          22
# 8                22           4
# 9                36          15
# 10               34          16
# 11               38          16
# 12               38          25
# 13                2           1
# 14                3           1
# 15               23          10
# 16                8           9
# 17               43          19
# 18               39          17

# %% [markdown]
# Now our data set is complete, cleaned up, and ready for analysis.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# Now that we have collected the required data, our next step will be to apply the machine learning technique **k-means** clustering to group the neighborhoods according to their number of medical centres and pharmacies present. **Our value of k will be 3 as we are looking to cluster the neighborhoods into 3 groups of greatest, medium, and least concern.**

# %%
from sklearn.cluster import KMeans 
clusterNum = 3

# %% [markdown]
# Let's declare our variable X which will be used for clustering. It will store the number of medical centres and pharmacies present in each neighbohood as an array. Normalization of the data is not required as the two features (number of medical centres and pharmacies) are of the same magnitude.

# %%
X = dt_df.values[:,6:8]

# %% [markdown]
# Initializing and fitting our k-means model:

# %%
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=12, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# The next step will be to assign each neighborhood to a cluster based on our k-means model, and add the corresponding cluster label for each neighborhood to the dataframe. Then, the clusters will be superimposed and visualized on a map of Toronto using folium.

# %% [markdown]
# ## Results <a name="results"></a>

# %% [markdown]
# Let's take a look at out cluster labels:

# %%
labels = k_means.labels_
print(labels)
# Out:
# [0 2 2 1 0 2 0 2 0 1 1 1 2 0 0 0 0 1 1]

# %% [markdown]
# We assign the labels to each row in our dataframe, dt_df, and view the dataframe:

# %%
dt_df['Cluster'] = labels
dt_df
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 1          M7A  Downtown Toronto
# 2          M5B  Downtown Toronto
# 3          M5C  Downtown Toronto
# 4          M5E  Downtown Toronto
# 5          M5G  Downtown Toronto
# 6          M6G  Downtown Toronto
# 7          M5H  Downtown Toronto
# 8          M5J  Downtown Toronto
# 9          M5K  Downtown Toronto
# 10         M5L  Downtown Toronto
# 11         M5S  Downtown Toronto
# 12         M5T  Downtown Toronto
# 13         M5V  Downtown Toronto
# 14         M4W  Downtown Toronto
# 15         M5W  Downtown Toronto
# 16         M4X  Downtown Toronto
# 17         M5X  Downtown Toronto
# 18         M4Y  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 0                           Regent Park, Harbourfront  43.654260 -79.360636
# 1         Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 2                            Garden District, Ryerson  43.657162 -79.378937
# 3                                      St. James Town  43.651494 -79.375418
# 4                                         Berczy Park  43.644771 -79.373306
# 5                                  Central Bay Street  43.657952 -79.387383
# 6                                            Christie  43.669542 -79.422564
# 7                            Richmond, Adelaide, King  43.650571 -79.384568
# 8   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 9            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 10                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 11                     University of Toronto, Harbord  43.662696 -79.400049
# 12          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 13  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 14                                           Rosedale  43.679563 -79.377529
# 15                                     Stn A PO Boxes  43.646435 -79.374846
# 16                        St. James Town, Cabbagetown  43.667967 -79.367675
# 17             First Canadian Place, Underground city  43.648429 -79.382280
# 18                               Church and Wellesley  43.665860 -79.383160
#
#     Medical Centres  Pharmacies  Cluster
# 0                 5           9        0
# 1                48          22        2
# 2                48          24        2
# 3                34          16        1
# 4                20          10        0
# 5                50          27        2
# 6                 9           9        0
# 7                48          22        2
# 8                22           4        0
# 9                36          15        1
# 10               34          16        1
# 11               38          16        1
# 12               38          25        2
# 13                2           1        0
# 14                3           1        0
# 15               23          10        0
# 16                8           9        0
# 17               43          19        1
# 18               39          17        1

# %% [markdown]
# Now, let's visualize our clusters on a map of Toronto.

# %%
# obtaining latitude and longitude coordinates of Toronto for mapping
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# Importing useful libraries for plotting:

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(clusterNum)
ys = [i + x + (i*x)**2 for i in range(clusterNum)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to map
for lat, lng, neighborhood, medical_centres, pharmacies, cluster in zip(dt_df['Latitude'], dt_df['Longitude'], dt_df['Neighborhood'], \
                                                                        dt_df['Medical Centres'], dt_df['Pharmacies'],dt_df['Cluster']):
    label = '{}, Medical Centres: {}, Pharmacies: {}, Cluster: {}'.format(neighborhood, medical_centres, pharmacies, cluster)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Discussion <a name="discussion"></a>

# %% [markdown]
# We now have a view of the neighborhoods in Downtown Toronto in which medical centres and pharmacies are concentrated. Based on this analysis we have identified 3 clusters/categories:

# %% [markdown]
# #### 1) Neighborhoods of Greatest Concern

# %%
dt_df[dt_df['Cluster'] == 0]
# Out:
#    Postal Code           Borough  \
# 0          M5A  Downtown Toronto
# 4          M5E  Downtown Toronto
# 6          M6G  Downtown Toronto
# 8          M5J  Downtown Toronto
# 13         M5V  Downtown Toronto
# 14         M4W  Downtown Toronto
# 15         M5W  Downtown Toronto
# 16         M4X  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 0                           Regent Park, Harbourfront  43.654260 -79.360636
# 4                                         Berczy Park  43.644771 -79.373306
# 6                                            Christie  43.669542 -79.422564
# 8   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 13  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 14                                           Rosedale  43.679563 -79.377529
# 15                                     Stn A PO Boxes  43.646435 -79.374846
# 16                        St. James Town, Cabbagetown  43.667967 -79.367675
#
#     Medical Centres  Pharmacies  Cluster
# 0                 5           9        0
# 4                20          10        0
# 6                 9           9        0
# 8                22           4        0
# 13                2           1        0
# 14                3           1        0
# 15               23          10        0
# 16                8           9        0

# %%
print("There are {} neighborhoods in the category 'Greatest Concern'.".format(len(dt_df[dt_df['Cluster'] == 0])))
# Out:
# There are 8 neighborhoods in the category 'Greatest Concern'.

# %% [markdown]
# These neighborhoods were identified to have the least number of either medical centres, pharmacies, or both. They are represented by <font color='red'>red circles</font> on our map of Toronto. These are areas where potential interventions (e.g. pop-up testing centres) may be focused by community and public health planning.

# %% [markdown]
# #### 2) Neighborhoods of Medium Concern

# %%
dt_df[dt_df['Cluster'] == 1]
# Out:
#    Postal Code           Borough                              Neighborhood  \
# 3          M5C  Downtown Toronto                            St. James Town
# 9          M5K  Downtown Toronto  Toronto Dominion Centre, Design Exchange
# 10         M5L  Downtown Toronto            Commerce Court, Victoria Hotel
# 11         M5S  Downtown Toronto            University of Toronto, Harbord
# 17         M5X  Downtown Toronto    First Canadian Place, Underground city
# 18         M4Y  Downtown Toronto                      Church and Wellesley
#
#      Latitude  Longitude  Medical Centres  Pharmacies  Cluster
# 3   43.651494 -79.375418               34          16        1
# 9   43.647177 -79.381576               36          15        1
# 10  43.648198 -79.379817               34          16        1
# 11  43.662696 -79.400049               38          16        1
# 17  43.648429 -79.382280               43          19        1
# 18  43.665860 -79.383160               39          17        1

# %%
print("There are {} neighborhoods in the category 'Medium Concern'.".format(len(dt_df[dt_df['Cluster'] == 1])))
# Out:
# There are 6 neighborhoods in the category 'Medium Concern'.

# %% [markdown]
# These neighborhoods were identified to have a medium number of medical centres and pharmacies. They are represented by <font color='purple'>purple circles</font> on our map of Toronto. These are areas where potential interventions (e.g. pop-up testing centres) may be needed but should likely not be the primary focus.

# %% [markdown]
# #### 3) Neighborhoods of Least Concern

# %%
dt_df[dt_df['Cluster'] == 2]
# Out:
#    Postal Code           Borough                                 Neighborhood  \
# 1          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2          M5B  Downtown Toronto                     Garden District, Ryerson
# 5          M5G  Downtown Toronto                           Central Bay Street
# 7          M5H  Downtown Toronto                     Richmond, Adelaide, King
# 12         M5T  Downtown Toronto    Kensington Market, Chinatown, Grange Park
#
#      Latitude  Longitude  Medical Centres  Pharmacies  Cluster
# 1   43.662301 -79.389494               48          22        2
# 2   43.657162 -79.378937               48          24        2
# 5   43.657952 -79.387383               50          27        2
# 7   43.650571 -79.384568               48          22        2
# 12  43.653206 -79.400049               38          25        2

# %%
print("There are {} neighborhoods in the category 'Least Concern'.".format(len(dt_df[dt_df['Cluster'] == 2])))
# Out:
# There are 5 neighborhoods in the category 'Least Concern'.

# %% [markdown]
# These neighborhoods were identified to have a high number of medical centres and pharmacies. They are represented by <font color='green'>green circles</font> on our map of Toronto. There are areas where potential interventions (e.g. pop-up centres) are the least needed.

# %% [markdown]
# #### Limitations and Further Analysis Required

# %% [markdown]
# A major limitation of this analysis is that it did not take into account the population of each neighborhood to properly assess its true medical access requirements. This is a feature that must be added for any further analysis. Some neighborhoods are also much nearer geographically to each other than others, which skews results as some venues may appear more than once while categorized under different neighborhoods. Furthermore, this study should be expanded to encompass all of Toronto and not just the downtown area.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# The purpose of this project was to group Toronto neighborhoods into 3 categories: Greatest Concern, Medium Concern, and Least Concern on the basis of the availability of medical centres and pharmacies in each neighborhood, as a response to the COVID-19 pandemic. This information is needed by Toronto Public Health, policy makers, and community leaders to determine which Toronto neighborhoods may be lacking access to adequate medical centres within walking distance. The data was successfully extracted and clustered into the 3 categories. The number of neighborhood groups falling into each category is as follows:
#
# * Greatest Concern: 8
# * Medium Concern: 6
# * Least Concern: 5
#
# However, further analysis is required to take into the account the population of each neighborhood and to segregate geographically close neighborhoods to get the full picture of medical access in each neighborhood.
